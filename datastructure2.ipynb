# %%
# Recursion function

# %%
def len_lcs(seq1,seq2):
    pass

# %%
T0 = {
    'input': {
        'seq1': 'serendipitous',
        'seq2': 'precipitation'
    },
    'output': 7
}

T1 = {
    'input': {
        'seq1': [1, 3, 5, 6, 7, 2, 5, 2, 3],
        'seq2': [6, 2, 4, 7, 1, 5, 6, 2, 3]
    },
    'output': 5
}

T2 = {
    'input': {
        'seq1': 'longest',
        'seq2': 'stone'
    },
    'output': 3
}

T3 = {
    'input': {
        'seq1': 'asdfwevad',
        'seq2': 'opkpoiklklj'
    },
    'output': 0
}

T4 = {
    'input': {
        'seq1': 'dense',
        'seq2': 'condensed'
    },
    'output': 5
}

T5 = {
    'input': {
        'seq1': '',
        'seq2': 'opkpoiklklj'
    },
    'output': 0
}

T6 = {
    'input': {
        'seq1': '',
        'seq2': ''
    },
    'output': 0
}

T7 = {
    'input': {
        'seq1': 'abcdef',
        'seq2': 'badcfe'
    },
    'output': 3
}

# %%
lcq_tests = [T0, T1, T2, T3, T4, T5, T6, T7]

# %%
def lcs_recursive(seq1,seq2,idx1=0,idx2=0):
    if idx1==len(seq1) or idx2==len(seq2):
        return 0
    elif seq1[idx1]==seq2[idx2]:
        return 1+ lcs_recursive(seq1,seq2,idx1+1,idx2+1)
    else:
        op1= lcs_recursive(seq1,seq2,idx1+1,idx2)
        op2=lcs_recursive(seq1,seq2,idx1,idx2+1)
        return max(op1,op2)

# %%
T0
# Out:
# {'input': {'seq1': 'serendipitous', 'seq2': 'precipitation'}, 'output': 7}

# %%
lcs_recursive(T0['input']['seq1'],'precipitation')
# Out:
# 7

# %%
lcs_recursive(T0['input']['seq1'],'precipitation')==T0['output']
# Out:
# True

# %%
lcs_recursive(T1['input']['seq1'],T1['input']['seq2'])==T1['output']
# Out:
# True

# %%
lcs_recursive(T3['input']['seq1'],T3['input']['seq2'])
# Out:
# 0

# %%
T3['output']
# Out:
# 0

# %%
# %%time
lcs_recursive('seredipitous', 'precipitation')
# Out:
# CPU times: total: 156 ms
# Wall time: 152 ms
# 7

# %%
# Dynamic Programming

def solve(n):


    if n < 0:
	    return 0
    if n == 0:
	    return 1

    return (solve(n - 1) +
		    solve(n - 3) +
		    solve(n - 5))

# %%
solve(9)
# Out:
# 30

# %%
solve(3)
# Out:
# 2

# %%
# Knapsack Solution

# %%
def max_profit(weights,profits,capacity):
    pass

# %%
def max_profit_recursive(capacity, weights, profits, idx=0):
    if idx == len(weights):
        return 0
    if weights[idx] > capacity:
        return max_profit_recursive(capacity, weights, profits, idx+1)
    else:
        return max(max_profit_recursive(capacity, weights, profits, idx+1),
                   profits[idx] + max_profit_recursive(capacity-weights[idx], weights, profits, idx+1))

# %%
test0 = {
    'input': {
        'capacity': 165,
        'weights': [23, 31, 29, 44, 53, 38, 63, 85, 89, 82],
        'profits': [92, 57, 49, 68, 60, 43, 67, 84, 87, 72]
    },
    'output': 309
}

test1 = {
    'input': {
        'capacity': 3,
        'weights': [4, 5, 6],
        'profits': [1, 2, 3]
    },
    'output': 0
}

test2 = {
    'input': {
        'capacity': 4,
        'weights': [4, 5, 1],
        'profits': [1, 2, 3]
    },
    'output': 3
}

# %%
max_profit_recursive(**test0['input'])
# Out:
# 309

# %%
max_profit_recursive(**test1['input'])
# Out:
# 0

# %%
max_profit_recursive(**test2['input'])
# Out:
# 3

# %%
# Graph data structure
num=5
ed=[(0,1),(0,4),(1,2),(1,3),(1,4),(2,3),(3,4)]

# %%
class Graph:
    def __init__(self,num,ed):
        self.num=num
        self.data=[[] for _ in range(num)]
        for  i,j in ed:
            self.data[i].append(j)
            self.data[j].append(i)
    def __repr__(self):
        return "\n".join(["{}:{}".format(n,ng) for n,ng in enumerate(self.data)])
    def __str__(self):
        return repr(self)

# %%
graph1=Graph(num,ed)

# %%
graph1.data
# Out:
# [[1, 4], [0, 2, 3, 4], [1, 3], [1, 2, 4], [0, 1, 3]]

# %%
graph1
# Out:
# 0:[1, 4]
# 1:[0, 2, 3, 4]
# 2:[1, 3]
# 3:[1, 2, 4]
# 4:[0, 1, 3]

# %%
# Breadth First Search
def bfs(graph, source):
    visited = [False] * len(graph.data)
    queue = []
    
    visited[source] = True    
    queue.append(source)
    i = 0
    
    while i < len(queue):
        for v in graph.data[queue[i]]:
            if not visited[v]:
                visited[v] = True
                queue.append(v)
        i += 1
        
    return queue

# %%
bfs(graph1, 3)
# Out:
# [3, 1, 2, 4, 0]

# %%
# Depth First Search
def dfs(graph, source):
    visited = [False] * len(graph.data)
    stack = [source]
    result = []
    
    while len(stack) > 0:
        current = stack.pop()
        if not visited[current]:
            result.append(current)
            visited[current] = True
            for v in graph.data[current]:
                stack.append(v)
                
    return result

# %%
dfs(graph1, 0)
# Out:
# [0, 4, 3, 2, 1]

# %%
# Python problem
ar=[1,7,4,2,1,3]
t=10
def subarray_sum1(arr, target):
    n = len(arr)
    for i in range(n):
        for j in range(i, n+1):
            if sum(arr[i:j]) == target:
                return i, j
    return None, None

# %%
subarray_sum1(ar,t)
# Out:
# (2, 6)

# %%
def subarray_sum3(arr, target):
    n = len(arr)
    i, j, s = 0, 0, 0
    while i < n and j <= n:
        if s == target:
            return i, j
        elif s < target:
            s += arr[j]
            j += 1
        elif s > target:
            s -= arr[i]
            i += 1
    return None, None

# %%
subarray_sum3(ar,t)
# Out:
# (2, 6)

# %%
str1="intention"
str2="execution"
ot=5
def min_step(str1,str2,i1=0,i2=0):
    if i1==len(str1):
        return len(str2) -i2
    elif i2==len(str2):
        return len(str1) -i1
    elif str1[i1]==str2[i2]:
        return min_step(str1,str2,i1+1,i2+1)
    else:
        return 1+ min(min_step(str1,str2,i1+1,i2+1),min_step(str1,str2,i1+1,i2+1),min_step(str1,str2,i1+1,i2+1))

# %%
min_step(str1,str2)
# Out:
# 5

# %%
min_step(str1,"exception")
# Out:
# 4

# %%
min_step('killing','billing')
# Out:
# 1

# %%
str1="intention"
str2="execution"
ot=5
def min_step(str1,str2,i1=0,i2=0):
    print(str1[i1:],str2[i2:])
    if i1==len(str1):
        return len(str2) -i2
    elif i2==len(str2):
        return len(str1) -i1
    elif str1[i1]==str2[i2]:
        return min_step(str1,str2,i1+1,i2+1)
    else:
        return 1+ min(min_step(str1,str2,i1+1,i2+1),min_step(str1,str2,i1+1,i2+1),min_step(str1,str2,i1+1,i2+1))

# %%
min_step('error','elephant')
# Out:
# error elephant
# rror lephant
# ror ephant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# ror ephant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# ror ephant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# or phant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# r hant
#  ant
#  ant
#  ant
# 7
